# %%
                     2nd February assignment
    
Q1. Explain with an example each when to use a for loop and a while loop.
Ans:- when do we use for loops 

actually, for loops are used when we have a block of code which we want to repeat a fixed number of times
and for-loop is always used in combination with an iterable object, like a list or a range. the python
for statement iterates over the members of a sequence in order, executing the block each time.

for example  
suppose we have to print tables then we already knew that the no of iteration will be 10,
here we will use for loops.

n=int(input("enter a number"))
i=range(1,11)
result=0
for i in i :
    result=n*i
    print(n,"x",i,"=",result)
    
when to use while loops

actually, the while loop is used when it is impossible to determine the exact number of loop iterations in advance.
for example,
check how many times a given number can be divided by 3 before it is less than or equal to 10

in this example we do not have any idea, haw many time will the loop execute.
in this case we should use while loop

count=0
n=int(input("enter a number"))
while n>=10:
    count=count+1
    n=n/3
print(count,"times can be devided by 3 before it is less than or equal to 10")

# %%
Q2. write a python program to print the sum and product of the first 10 natural number using for and while loop.

Ans:- 
#using for loop
su_m=0
product =1

i=range(1,11)
for k in i :
    su_m=su_m+k
    product=product*k
    i=i+1
    
print("sum of first 10 natural numbers is" , su_m,"\nproduct of first 10 natural number is",product)

# %%
Q3.
Ans:-

bill=0
temp=0
temp1=0
temp2=0
units=int(input("enter your unit:-"))

if units >0 and units<=100:
    bill=units*4.5
    print("total electricity bill =",bill)
    
elif units >100 and units<=200:
    temp=4.5*100
    units=units%100
    bill=units*6+temp
    print("total electricity bill =",bill)
    
elif units >100 and units<=200:
    temp=4.5*100
    temp1=6*100
    units=units%200
    bill=units*10+temp+temp1
    print("total electricity bill =",bill)
    

elif units >100 and units<=200:
    temp=4.5*100
    temp1=6*100
    tesmp2=10*100
    units=units%300
    bill=units*20+temp+temp1+temp2
    print("total electricity bill =",bill)

# %%
Q4.
Ans:-

#using while and for loop

i=1

l_cube=[]
l_divisible_by_4_or_5=[]

while i <=100:
    l_cube.append(i**3)
    i=i+1
else:
    for j in l_cube:
        if j%4==0 or j%5==0:
            l_divisible_by_4_or_5.append(j)
print("cube of each numbers\n\n",l_cube)
print("\n\n divisible by 4 or 5\n\n",l_divisible_by_4_or_5)

# using only for loop

l=list(range(1,101))

l_cube=[]
l_divisible_by_4_or_5=[]

for i in l:
    l_cube.append(i**3)
else:
    for j in l_cube:
        if j%4==0 or j%5==0:
            l_divisible_by_4_or_5.append(j)
print("cube of each numbers\n\n",l_divisible_by_4_or_5)

# %%
Q5.
Ans:-

string="i want to become dfata scientist"
vowels=['a','e','i','o','u','A','E','I','O','U']
total_vowels=0
count=0
for i in vowels:
    count=string.count(i)
    total_vowels=
